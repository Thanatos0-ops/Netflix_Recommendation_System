# %%
#! importing libraries

import pandas as pd
import numpy as np

# %%
# loading data

credits = pd.read_csv("../Data/raw/credits.csv")
movies_metadata = pd.read_csv("../Data/raw/movies_metadata.csv")
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_24532\965213456.py:4: DtypeWarning: Columns (0: popularity) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_metadata = pd.read_csv("../Data/raw/movies_metadata.csv")

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Convert release_date to datetime

movies_metadata["release_date"] = pd.to_datetime(movies_metadata["release_date"], errors="coerce") # Convert to datetime, error = "coerce" convert invalid dates to NaN

# %%
# format the date to year only

movies_metadata['year'] = movies_metadata['release_date'].dt.year

# %%
movies_metadata["year"].value_counts().sort_index()
# Out:
# year
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: count, Length: 135, dtype: int64

# %%
# Getting only 2017 data as we already have movies data until 2016

movies_metadata_2017 = movies_metadata.loc[movies_metadata["year"] == 2017, ["id", "title", "year", "genres"]]

# %%
movies_metadata_2017
# Out:
#            id                                             title    year  \
# 26560  166426  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 26561  141052                                    Justice League  2017.0
# 26565  284053                                    Thor: Ragnarok  2017.0
# 26566  283995                    Guardians of the Galaxy Vol. 2  2017.0
# 30536  245842                               The King's Daughter  2017.0
# ...       ...                                               ...     ...
# 45398  468707                  Thick Lashes of Lauri Mäntyvaara  2017.0
# 45417  461297                       Cop and a Half: New Recruit  2017.0
# 45437  455661                                    In a Heartbeat  2017.0
# 45453  404604                                               Mom  2017.0
# 45465  461257                                          Queerama  2017.0
#
#                                                   genres
# ...

# %%
movies_metadata_2017.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 532 entries, 26560 to 45465
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      532 non-null    str
#  1   title   532 non-null    str
#  2   year    532 non-null    float64
#  3   genres  532 non-null    str
# dtypes: float64(1), str(3)
# memory usage: 20.8 KB

# %%
movies_metadata_2017["id"] = movies_metadata_2017["id"].astype(int)

# %%
df = pd.merge(movies_metadata_2017, credits, on="id")

# %%
df.head()
# Out:
#        id                                             title    year  \
# 0  166426  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 1  141052                                    Justice League  2017.0
# 2  284053                                    Thor: Ragnarok  2017.0
# 3  283995                    Guardians of the Galaxy Vol. 2  2017.0
# 4  245842                               The King's Daughter  2017.0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
#
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Captain Jack Spa...
# 1  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 2  [{'cast_id': 0, 'character': 'Thor Odinson', '...
# ...

# %%
import ast


df['genres'] = df['genres'].map(lambda x: ast.literal_eval(x))
df['cast'] = df['cast'].map(lambda x: ast.literal_eval(x))
df['crew'] = df['crew'].map(lambda x: ast.literal_eval(x))

# %%
df.head()
# Out:
#        id                                             title    year  \
# 0  166426  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 1  141052                                    Justice League  2017.0
# 2  284053                                    Thor: Ragnarok  2017.0
# 3  283995                    Guardians of the Galaxy Vol. 2  2017.0
# 4  245842                               The King's Daughter  2017.0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
#
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Captain Jack Spa...
# 1  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 2  [{'cast_id': 0, 'character': 'Thor Odinson', '...
# ...

# %%
def get_individual_genres(genres):
    gen = []
    st = ' '
    for i in genres:
        if i.get("name") == "Science Fiction":
            gen.append("Sci-Fi")
        else:
            gen.append(i.get("name"))
    
    if gen == []:
        return np.nan
    
    return st.join(gen)

# %%
df['genres_list'] = df['genres'].map(lambda x: get_individual_genres(x))

# %%
df['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: str

# %%
def get_actor_1(cast):
    casts = []
    for i in cast:
        casts.append(i.get("name"))
    if casts == []:
        return np.nan
    else:
        return casts[0]

# %%
df['actor_1_name'] = df['cast'].map(lambda x: get_actor_1(x))

# %%
def get_actor_2(cast):
    casts = []
    for i in cast:
        casts.append(i.get("name"))
    if len(casts) < 2:
        return np.nan
    else:
        return casts[1]

# %%
df['actor_2_name'] = df['cast'].map(lambda x: get_actor_2(x))

# %%
def get_actor_3(cast):
    casts = []
    for i in cast:
        casts.append(i.get("name"))
    if len(casts) < 3:
        return np.nan
    else:
        return casts[2]

# %%
df['actor_3_name'] = df['cast'].map(lambda x: get_actor_3(x))

# %%
def get_director(crew):
    dt = []
    st = ' '
    for i in crew:
        if i.get("job") == "Director":
            dt.append(i.get("name"))
    if dt == []:
        return np.nan
    else:
        return st.join(dt)

# %%
df['director_name'] = df['crew'].map(lambda x: get_director(x))

# %%
df.head()
# Out:
#        id                                             title    year  \
# 0  166426  Pirates of the Caribbean: Dead Men Tell No Tales  2017.0
# 1  141052                                    Justice League  2017.0
# 2  284053                                    Thor: Ragnarok  2017.0
# 3  283995                    Guardians of the Galaxy Vol. 2  2017.0
# 4  245842                               The King's Daughter  2017.0
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 4  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
#
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Captain Jack Spa...
# 1  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 2  [{'cast_id': 0, 'character': 'Thor Odinson', '...
# ...

# %%
# Selecting the same columns as per the previous dataset

df = df.loc[:, ["director_name", "actor_1_name", "actor_2_name", "actor_3_name", "genres_list", "title"]]
df.head()
# Out:
#                     director_name     actor_1_name    actor_2_name  \
# 0  Joachim Rønning Espen Sandberg      Johnny Depp   Javier Bardem
# 1                     Zack Snyder      Ben Affleck    Henry Cavill
# 2                   Taika Waititi  Chris Hemsworth  Tom Hiddleston
# 3                      James Gunn      Chris Pratt     Zoe Saldana
# 4                   Sean McNamara   Pierce Brosnan    William Hurt
#
#       actor_3_name                      genres_list  \
# 0    Geoffrey Rush  Adventure Action Fantasy Comedy
# 1        Gal Gadot  Action Adventure Fantasy Sci-Fi
# 2   Cate Blanchett  Action Adventure Fantasy Sci-Fi
# 3    Dave Bautista   Action Adventure Comedy Sci-Fi
# 4  Benjamin Walker         Fantasy Action Adventure
#
#                                               title
# 0  Pirates of the Caribbean: Dead Men Tell No Tales
# 1                                    Justice League
# 2                                    Thor: Ragnarok
# ...

# %%
df.isna().sum()
# Out:
# director_name     4
# actor_1_name     22
# actor_2_name     55
# actor_3_name     70
# genres_list       7
# title             0
# dtype: int64

# %%
df.shape
# Out:
# (531, 6)

# %%
df.dropna(how="any", inplace=True)

# %%
df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
df.shape
# Out:
# (458, 6)

# %%
df = df.rename(columns={"title": "movie_title"})
df = df.rename(columns={"genres_list": "genres"})

# %%
df['movie_title'] = df['movie_title'].str.lower()

# %%
df['comb'] = df['actor_1_name'] + ' ' + df['actor_2_name'] + ' ' + df['actor_3_name'] + ' ' + df['director_name'] + ' ' + df['genres']

# %%
df.head()
# Out:
#                     director_name     actor_1_name    actor_2_name  \
# 0  Joachim Rønning Espen Sandberg      Johnny Depp   Javier Bardem
# 1                     Zack Snyder      Ben Affleck    Henry Cavill
# 2                   Taika Waititi  Chris Hemsworth  Tom Hiddleston
# 3                      James Gunn      Chris Pratt     Zoe Saldana
# 4                   Sean McNamara   Pierce Brosnan    William Hurt
#
#       actor_3_name                           genres  \
# 0    Geoffrey Rush  Adventure Action Fantasy Comedy
# 1        Gal Gadot  Action Adventure Fantasy Sci-Fi
# 2   Cate Blanchett  Action Adventure Fantasy Sci-Fi
# 3    Dave Bautista   Action Adventure Comedy Sci-Fi
# 4  Benjamin Walker         Fantasy Action Adventure
#
#                                         movie_title  \
# 0  pirates of the caribbean: dead men tell no tales
# 1                                    justice league
# 2                                    thor: ragnarok
# ...

# %%
df.to_csv("../Data/processed/movie_metadata_2017.csv", index=False)

# %%
old = pd.read_csv("../Data/processed/processed_movie_metadata.csv")
old.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' ' + old['actor_3_name'] + ' ' + old['director_name'] + ' ' + old['genres']

# %%
old.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
new = pd.concat([old, df])
new.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# ...

# %%
new.shape
# Out:
# (5501, 7)

# %%
new.duplicated().sum()
# Out:
# np.int64(123)

# %%
new.drop_duplicates(subset = "movie_title", keep="last",inplace=True)
new
# Out:
#              director_name          actor_1_name            actor_2_name  \
# 0            James Cameron           CCH Pounder        Joel David Moore
# 1           Gore Verbinski           Johnny Depp           Orlando Bloom
# 2               Sam Mendes       Christoph Waltz            Rory Kinnear
# 3        Christopher Nolan             Tom Hardy          Christian Bale
# 4              Doug Walker           Doug Walker              Rob Walker
# ..                     ...                   ...                     ...
# 524            Jim Strouse      Jessica Williams            Chris O'Dowd
# 525            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 526       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 529           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#              actor_3_name                           genres  \
# ...

# %%
new.to_csv("../Data/processed/processed_combined_movie_metadata.csv", index=False)
